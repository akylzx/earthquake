# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.preprocessing import StandardScaler
import lightgbm as lgb
from sklearn.model_selection import KFold
from sklearn.multioutput import MultiOutputRegressor
import warnings
warnings.filterwarnings("ignore")


SEED = 42
n_splits = 8
n_estimators=5000
early_stopping_rounds = 100

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")
eq_df = pd.read_csv("eq.csv")
sample_submission = pd.read_csv("sample_submission.csv")



# test_df.describe()
# test_df.describe()
# test_df.info()
train_df.info()
train_df = train_df.drop(columns=["Unnamed: 0"])

print(f"Training data shape: {train_df.shape}")
print(f"Earthquake data shape: {eq_df.shape}")
print(f"Test data shape: {test_df.shape}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1250 non-null   int64
#  1   year        1250 non-null   int64
#  2   month       1250 non-null   int64
#  3   day         1250 non-null   int64
#  4   hour        1250 non-null   int64
#  5   min         1250 non-null   int64
#  6   sec         1250 non-null   int64
#  7   lat         1250 non-null   float64
#  8   lon         1250 non-null   float64
#  9   depth       1250 non-null   int64
#  10  class       1250 non-null   float64
#  11  year_as     1250 non-null   int64
#  12  month_as    1250 non-null   int64
#  13  day_as      1250 non-null   int64
#  14  hour_as     1250 non-null   int64
#  15  min_as      1250 non-null   int64
#  16  sec_as      1250 non-null   int64
#  17  lat_as      1250 non-null   float64
#  18  lon_as      1250 non-null   float64
#  19  depth_as    1250 non-null   int64
#  20  class_as    1250 non-null   float64
# dtypes: float64(6), int64(15)
# memory usage: 205.2 KB
# Training data shape: (1250, 20)
# Earthquake data shape: (72284, 10)
# Test data shape: (300, 11)

# %%
target_cols = ["year_as", "month_as", "day_as", "hour_as", "min_as", "sec_as",
                  "lat_as", "lon_as", "depth_as", "class_as"]

X = train_df.drop(columns=target_cols)
y = train_df[target_cols]

X_test = test_df[X.columns].copy()

# %%
nFolds = 7
cv = KFold(n_splits=nFolds, random_state=SEED, shuffle=True)

predictions = {col: np.zeros(len(X_test)) for col in target_cols}

for col in target_cols:
    fold_preds = np.zeros(len(X_test))
    print(f"Training for target: {col}")
    for train_idx, valid_idx in cv.split(X, y):
        X_train, y_train = X.iloc[train_idx].copy(), y.iloc[train_idx][col]
        X_valid, y_valid = X.iloc[valid_idx].copy(), y.iloc[valid_idx][col]
        
        model = lgb.LGBMRegressor(
            n_estimators=1000,
            max_depth=-1,
            num_leaves=1024,
            colsample_bytree=0.7,
            learning_rate=0.03,
            objective='regression',
            metric='mae',
            verbosity=-1,  
            device='gpu',  
            random_state=87
        )
        
        model.fit(
            X_train, y_train,
            eval_set=[(X_valid, y_valid)],
            eval_metric='mae',
            callbacks=[lgb.early_stopping(stopping_rounds=early_stopping_rounds, verbose=True)]
        )


        
        fold_preds += model.predict(X_test) / nFolds
    predictions[col] = fold_preds
# Out:
# Training for target: year_as
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [995]	valid_0's l1: 0.468006
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [809]	valid_0's l1: 0.43077
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [996]	valid_0's l1: 0.472861
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [611]	valid_0's l1: 0.398632
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [947]	valid_0's l1: 0.392085
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [902]	valid_0's l1: 0.369031
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [885]	valid_0's l1: 0.402725
# Training for target: month_as
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [283]	valid_0's l1: 0.341755
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [287]	valid_0's l1: 0.361143
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [218]	valid_0's l1: 0.331327
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [499]	valid_0's l1: 0.375927
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [311]	valid_0's l1: 0.328854
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [265]	valid_0's l1: 0.348722
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [501]	valid_0's l1: 0.357348
# Training for target: day_as
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [198]	valid_0's l1: 4.43025
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [172]	valid_0's l1: 4.26454
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [130]	valid_0's l1: 3.75697
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [172]	valid_0's l1: 4.62597
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [308]	valid_0's l1: 4.20343
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [136]	valid_0's l1: 4.6228
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [188]	valid_0's l1: 4.36836
# Training for target: hour_as
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [154]	valid_0's l1: 5.49357
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	valid_0's l1: 5.39834
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [144]	valid_0's l1: 5.20389
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [65]	valid_0's l1: 5.32512
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [91]	valid_0's l1: 5.32754
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [141]	valid_0's l1: 4.93193
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [149]	valid_0's l1: 4.95979
# Training for target: min_as
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [59]	valid_0's l1: 14.7037
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	valid_0's l1: 14.4898
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	valid_0's l1: 14.9859
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [57]	valid_0's l1: 14.3049
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	valid_0's l1: 15.678
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	valid_0's l1: 14.3732
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	valid_0's l1: 14.6653
# Training for target: sec_as
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	valid_0's l1: 148.406
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's l1: 153.449
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	valid_0's l1: 164.494
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l1: 154.248
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [55]	valid_0's l1: 145.233
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's l1: 151.533
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	valid_0's l1: 143.125
# Training for target: lat_as
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [991]	valid_0's l1: 0.114975
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [594]	valid_0's l1: 0.142318
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [446]	valid_0's l1: 0.139204
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [748]	valid_0's l1: 0.137664
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [532]	valid_0's l1: 0.129187
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [991]	valid_0's l1: 0.143582
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [996]	valid_0's l1: 0.112221
# Training for target: lon_as
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [477]	valid_0's l1: 0.185549
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [341]	valid_0's l1: 0.204917
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [440]	valid_0's l1: 0.17123
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [448]	valid_0's l1: 0.184429
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [399]	valid_0's l1: 0.171855
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [355]	valid_0's l1: 0.214274
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [570]	valid_0's l1: 0.181327
# Training for target: depth_as
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [119]	valid_0's l1: 4.10565
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [113]	valid_0's l1: 3.82104
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [121]	valid_0's l1: 3.79345
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [100]	valid_0's l1: 4.49047
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [119]	valid_0's l1: 3.93128
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [96]	valid_0's l1: 4.11653
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [115]	valid_0's l1: 4.66161
# Training for target: class_as
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [114]	valid_0's l1: 0.851088
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [159]	valid_0's l1: 0.725224
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [119]	valid_0's l1: 0.824888
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [136]	valid_0's l1: 0.797182
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [91]	valid_0's l1: 0.798841
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [197]	valid_0's l1: 0.735819
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [77]	valid_0's l1: 0.807312

# %%
submission = pd.DataFrame({
    'id_eq': test_df['id_eq'],
    'year_as': predictions['year_as'],
    'month_as': predictions['month_as'],
    'day_as': predictions['day_as'],
    'hour_as': predictions['hour_as'],
    'min_as': predictions['min_as'],
    'sec_as': predictions['sec_as'],
    'lat_as': predictions['lat_as'],
    'lon_as': predictions['lon_as'],
    'depth_as': predictions['depth_as'],
    'class_as': predictions['class_as']
})

submission.to_csv('submission.csv', index=False)
print('Submission file saved as submission.csv')
# Out:
# Submission file saved as submission.csv
